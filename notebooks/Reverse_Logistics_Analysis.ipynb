# %%
from pathlib import Path

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
raw_data_path = project_root / 'data' / 'raw' / 'returns_sustainability_dataset.csv'
processed_data_path = project_root / 'data' / 'processed' / 'returns_cleaned_for_sql_powerbi.csv'

df = pd.read_csv(raw_data_path)
df.head()

# We loaded the dataset to our notebook and displayed the first five rows
# Out:
#    order_id product_id   user_id  order_date product_category  product_price  \
# 0  ORD00000   PROD0169  USER0195  2022-01-14         Clothing        1720.71
# 1  ORD00001   PROD0318  USER1469  2022-01-03             Toys         744.06
# 2  ORD00002   PROD0427  USER1812  2025-03-16         Clothing         983.68
# 3  ORD00003   PROD0323  USER1274  2024-11-06            Books        1855.65
# 4  ORD00004   PROD0325  USER0551  2023-06-07  Home Appliances        1770.97
#
#    order_quantity  discount_applied shipping_method payment_method  ...  \
# 0               2             30.46        Next-Day         Wallet  ...
# 1               5             29.62        Next-Day         Wallet  ...
# 2               5             47.80         Express         Wallet  ...
# 3               2              2.90         Express            COD  ...
# 4               5             44.42         Express            COD  ...
#
#    return_cost  profit_loss co2_emissions packaging_waste co2_saved  \
# 0            0  2393.163468           2.0             0.4       2.0
# 1          200  2418.347140           2.0             1.0       0.0
# 2            0  2567.404800           1.5             1.0       1.5
# 3            0  3603.672300           1.5             0.4       1.5
# 4          200  4721.525630           1.5             1.0       0.0
#
#    waste_avoided  returned  order_month  order_year      discount_bin
# 0            0.4     False      2022-01        2022    (25.02, 37.38]
# 1            0.0      True      2022-01        2022    (25.02, 37.38]
# 2            1.0     False      2025-03        2025     (37.38, 50.0]
# 3            0.4     False      2024-11        2024  (-0.001, 12.828]
# 4            0.0      True      2023-06        2023     (37.38, 50.0]
#
# [5 rows x 27 columns]

# %%
df.shape
# We can understand that we have 5000 rows and 27 columns in the dataset
# Out:
# (5000, 27)

# %%
df.columns = df.columns.str.lower()
df.columns

# Column names were in Sentence case, so converted them to lower case. This is much easier while working.
# Out:
# Index(['order_id', 'product_id', 'user_id', 'order_date', 'product_category',
#        'product_price', 'order_quantity', 'discount_applied',
#        'shipping_method', 'payment_method', 'user_age', 'user_gender',
#        'user_location', 'return_status', 'return_reason', 'days_to_return',
#        'order_value', 'return_cost', 'profit_loss', 'co2_emissions',
#        'packaging_waste', 'co2_saved', 'waste_avoided', 'returned',
#        'order_month', 'order_year', 'discount_bin'],
#       dtype='object')

# %%
df.dtypes
# Checking the data type of the content present in each column
# Out:
# order_id             object
# product_id           object
# user_id              object
# order_date           object
# product_category     object
# product_price       float64
# order_quantity        int64
# discount_applied    float64
# shipping_method      object
# payment_method       object
# user_age              int64
# user_gender          object
# user_location        object
# return_status        object
# return_reason        object
# days_to_return        int64
# order_value         float64
# return_cost           int64
# profit_loss         float64
# co2_emissions       float64
# packaging_waste     float64
# co2_saved           float64
# waste_avoided       float64
# returned               bool
# order_month          object
# order_year            int64
# discount_bin         object
# dtype: object

# %%
df.isnull().sum()
# We are checking, whether there are any null values in the datasets by using 'isnull()'
# Using '.sum()' gives us total number of null values in the dataset by adding the count.
# Out:
# order_id            0
# product_id          0
# user_id             0
# order_date          0
# product_category    0
# product_price       0
# order_quantity      0
# discount_applied    0
# shipping_method     0
# payment_method      0
# user_age            0
# user_gender         0
# user_location       0
# return_status       0
# return_reason       0
# days_to_return      0
# order_value         0
# return_cost         0
# profit_loss         0
# co2_emissions       0
# packaging_waste     0
# co2_saved           0
# waste_avoided       0
# returned            0
# order_month         0
# order_year          0
# discount_bin        0
# dtype: int64

# %%
df['returned'] = (
    df['return_status']
    .astype(str)
    .str.lower()
    .eq('returned')
)

# The `Returned` column is derived from `Return_Status` to create a consistent boolean flag for 
# KPI calculations and downstream BI usage.

# %%
# Adding time features (Years, Months)
df['order_date'] = pd.to_datetime(df['order_date'], errors = 'coerce')
df['order_month'] = df['order_date'].dt.to_period('M').astype(str)
df['order_year'] = df['order_date'].dt.year

# %%
df[['order_date', 'order_month', 'order_year']].head()
# Out:
#   order_date order_month  order_year
# 0 2022-01-14     2022-01        2022
# 1 2022-01-03     2022-01        2022
# 2 2025-03-16     2025-03        2025
# 3 2024-11-06     2024-11        2024
# 4 2023-06-07     2023-06        2023

# %%
# Performing Consistency Check
df[(df['returned'] == False) & (df['return_cost'] > 0)].shape[0]

# We wrote this line to check whether the product is NOT RETURNED and there is no return cost for that.
# Out:
# 0

# %%
# Core KPI
# Answering: How big is the returning problem?
# Answering: What is the financial Impact?

total_orders = len(df) # Total number of orders calculated
returned_orders = df['returned'].sum() # Getting the number of orders where the product is returned
return_rate = (returned_orders/total_orders) * 100 # Percentage of return rate

total_return_cost = df.loc[df['returned'], 'return_cost'].sum()
# We are using .loc to determine the value from return_cost column, only if the returned column brings up "returned"
avg_return_cost = df.loc[df['returned'], 'return_cost'].mean()
# Similar to the above line we are finding the average, by using df.loc.

print('Total Orders:',total_orders)
print('Total number of orders returned:',returned_orders)
print('Rate of return:',round(return_rate,2),'%')
print('Total return cost:',total_return_cost)
print('Average return cost:',avg_return_cost)
# Out:
# Total Orders: 5000
# Total number of orders returned: 1450
# Rate of return: 29.0 %
# Total return cost: 290000
# Average return cost: 200.0

# %%
# Returns reason analysis
reason_counts = df.loc[df['returned'], 'return_reason'].value_counts()
print(reason_counts)
# Doing the above step gives up the count of reasons for the products being returned
# Out:
# return_reason
# Defective       382
# Changed Mind    379
# Wrong Item      348
# Size Issue      341
# Name: count, dtype: int64

# %%
# Category-level analysis
cat_summary = df.loc[df['returned'], 'product_category'].value_counts()
cat_summary
# Out:
# product_category
# Clothing           661
# Electronics        314
# Toys               181
# Books              172
# Home Appliances    122
# Name: count, dtype: int64

# %%
# Product Category-level anaylsis
cat_summary = df.groupby("product_category").agg(
    orders=("returned", "size"),
    returns=("returned", "sum"),
    return_rate=("returned", "mean")
)

# %%
# Location wise analysis (Where returns are more)
df[df['returned']].groupby('user_location').size()
# Out:
# user_location
# City1      14
# City10     14
# City100    14
# City11     14
# City12     17
#            ..
# City95     14
# City96     14
# City97     14
# City98     13
# City99     13
# Length: 100, dtype: int64

# %%
# Time trend (when returns are high)
monthly = df.groupby(
    pd.Grouper(key = 'order_date', freq = 'ME'))['returned'].mean()
monthly
# Out:
# order_date
# 2022-01-31    0.272727
# 2022-02-28    0.288288
# 2022-03-31    0.215686
# 2022-04-30    0.288136
# 2022-05-31    0.256198
# 2022-06-30    0.233871
# 2022-07-31    0.297521
# 2022-08-31    0.285714
# 2022-09-30    0.263636
# 2022-10-31    0.271845
# 2022-11-30    0.235294
# 2022-12-31    0.264000
# 2023-01-31    0.220183
# 2023-02-28    0.262626
# 2023-03-31    0.358974
# 2023-04-30    0.363636
# 2023-05-31    0.278689
# 2023-06-30    0.260000
# 2023-07-31    0.308511
# 2023-08-31    0.258065
# 2023-09-30    0.300885
# 2023-10-31    0.350427
# 2023-11-30    0.302752
# 2023-12-31    0.293103
# 2024-01-31    0.294643
# 2024-02-29    0.338583
# 2024-03-31    0.296296
# 2024-04-30    0.269565
# 2024-05-31    0.381818
# 2024-06-30    0.271028
# 2024-07-31    0.352459
# 2024-08-31    0.284553
# 2024-09-30    0.358696
# 2024-10-31    0.342857
# 2024-11-30    0.280374
# 2024-12-31    0.300000
# 2025-01-31    0.236842
# 2025-02-28    0.367347
# 2025-03-31    0.248062
# 2025-04-30    0.339623
# 2025-05-31    0.234375
# 2025-06-30    0.258929
# 2025-07-31    0.346774
# 2025-08-31    0.277311
# 2025-09-30    0.125000
# Freq: ME, Name: returned, dtype: float64

# %%
# Operational Drivers (How business decision affect)
shipping_returns = df.groupby('shipping_method')['returned'].mean()
payment_returns = df.groupby('payment_method')['returned'].mean()

# %%
# Discount Analysis
df['discount_bin'] = pd.qcut(df["discount_applied"], 4)

# %%
print(f"Overall return rate: {return_rate:.2f}%")
# Out:
# Overall return rate: 29.00%

# %%
df.to_csv(processed_data_path, index=False)
